# %% [markdown]
# <a href="https://colab.research.google.com/github/Falgon-Official/FirstProject/blob/dev/first_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PDA Education Email</title>
    <style>
        body {
            margin: 0;
            padding: 0;
            font-family: Arial, sans-serif;
            background-color: #f4f4f4;
        }

        .email-container {
            max-width: 600px;
            margin: 20px auto;
            background-color: #ffffff;
            border-radius: 10px;
            box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
            overflow: hidden;
        }

        .header {
            background: url('logo.PNG');
            background-size: cover;
            background-position: center;
            padding: 50px 10px;
            text-align: center;
            color: #ffffff;
        }

        .header h1 {
            font-size: 24px;
            margin: 0;
        }

        .content {
            padding: 20px;
            color: #333;
        }

        .content h2 {
            font-size: 20px;
            color: #7b16b5;
        }

        .content p {
            line-height: 1.6;
            font-size: 16px;
            margin: 10px 0;
        }

        .content ul {
            padding-left: 20px;
        }

        .content ul li {
            margin: 5px 0;
        }

        .content .button {
            display: inline-block;
            padding: 10px 20px;
            background-color: #c450bc;
            color: #ffffff;
            text-decoration: none;
            border-radius: 5px;
            margin-top: 20px;
            text-align: center;
        }

        .social-buttons {
            margin-top: 20px;
            text-align: center;
        }

        .social-buttons a {
            display: inline-block;
            margin: 0 10px;
            padding: 10px 20px;
            background-color: #7b16b5;
            color: #ffffff;
            text-decoration: none;
            border-radius: 5px;
            font-size: 14px;
        }

        .social-buttons a.facebook {
            background-color: #4267B2;
        }

        .social-buttons a.gmail {
            background-color: #D44638;
        }

        .social-buttons a.whatsapp {
            background-color: #25D366;
        }

        .footer {
            padding: 10px;
            text-align: center;
            font-size: 12px;
            color: #666;
            background-color: #f1f1f1;
        }

        /* Responsive Design */
        @media screen and (max-width: 768px) {
            .header {
                padding: 30px 10px;
            }

            .header h1 {
                font-size: 20px;
            }

            .content {
                padding: 15px;
            }

            .content h2 {
                font-size: 18px;
            }

            .content p {
                font-size: 14px;
            }

            .content .button {
                padding: 8px 15px;
                font-size: 14px;
            }

            .social-buttons a {
                padding: 8px 15px;
                font-size: 12px;
            }
        }

        @media screen and (max-width: 480px) {
            .header {
                padding: 20px 10px;
            }

            .header h1 {
                font-size: 18px;
            }

            .content {
                padding: 10px;
            }

            .content h2 {
                font-size: 16px;
            }

            .content p {
                font-size: 12px;
            }

            .content .button {
                padding: 6px 10px;
                font-size: 12px;
            }

            .social-buttons a {
                padding: 6px 10px;
                font-size: 10px;
            }
        }
    </style>
</head>
<body>

<div class="email-container">
    <!-- Header Section -->
    <div class="header">
        <h1>Digital Marketing Trends and Innovation 2025</h1>
    </div>

    <!-- Content Section -->
    <div class="content">
        <h2>Welcome to PDA!</h2>
        <p>We are thrilled to bring you the latest insights and innovations in digital marketing for 2025. Discover cutting-edge trends that will shape the industry and learn how you can stay ahead of the curve.</p>

        <h2>What You Can Expect</h2>
        <p>Join us in exploring topics like:</p>
        <ul>
            <li>Emerging technologies in digital marketing</li>
            <li>Innovative strategies for better engagement</li>
            <li>Success stories from leading experts</li>
        </ul>

        <h2>Digital Marketing Trends and Innovations 2025</h2>
        <p>As we enter 2025, digital marketing is rapidly evolving. Here are the key trends to watch:</p>
        <ul>
            <li><strong>AI-Powered Marketing:</strong> AI is enhancing customer personalization, predictive analytics, and automating marketing processes.</li>
            <li><strong>Voice Search Optimization:</strong> Optimizing for voice search is crucial as voice-activated devices become more widespread.</li>
            <li><strong>Interactive Content:</strong> Video, quizzes, polls, and AR are creating more engaging experiences for consumers.</li>
            <li><strong>Social Commerce:</strong> Social media platforms like Instagram and Facebook are becoming direct shopping destinations.</li>
            <li><strong>Data Privacy and Security:</strong> With growing concerns about data, transparency in data collection and usage is more important than ever.</li>
        </ul>

        <a href="https://www.facebook.com/pdafb" class="button">Learn More</a>

        <div class="social-buttons">
            <div class="social-buttons">
                <a href="https://web.facebook.com/pdafb" class="facebook">
                    <img src="images (1).jpeg" alt="Facebook" style="width: 20px; height: 20px; margin-right: 8px; vertical-align: middle;">
                </a>
                <a href="mailto:prashantadey.pda@gmail.com" class="gmail">
                    <img src="images.jpeg" alt="Gmail" style="width: 20px; height: 20px; margin-right: 8px; vertical-align: middle;">
                </a>
                <a href="https://wa.me/8801796463386" class="whatsapp">
                    <img src="images.png" alt="WhatsApp" style="width: 20px; height: 20px; margin-right: 8px; vertical-align: middle;">
                </a>
            </div>
            <!-- <a href="https://www.facebook.com/pdafb" class="facebook">Facebook</a> -->
            <!-- <a href="mailto:prashantadey.pda@gmail.com" class="gmail">Gmail</a> -->
            <!-- <a href="https://wa.me/8801796463386" class="whatsapp">WhatsApp</a> -->
        </div>
    </div>

    <!-- Footer Section -->
    <div class="footer">
        <p>&copy; 2025 PDA. All rights reserved.</p>

</div>

</body>
</html>
